# %% [markdown]
# # Section 1

# %% [markdown]
# ### Installed Packages List

# %% [markdown]
# C:\Users\Jenna>python -m pip list
# Package                           Version
# --------------------------------- -----------------
# appdirs                           1.4.4
# arcgis                            2.0.1
# asn1crypto                        1.4.0
# atomicwrites                      1.4.0
# attrs                             21.4.0
# azure-core                        1.12.0
# azure-storage-blob                12.8.0
# backcall                          0.2.0
# black                             0.0.0
# bleach                            4.1.0
# blinker                           1.4
# Bottleneck                        1.3.4
# brotlipy                          0.7.0
# cached-property                   1.5.2
# cachetools                        4.2.2
# certifi                           2021.10.8
# cffi                              1.15.0
# cftime                            1.5.0
# chardet                           4.0.0
# charset-normalizer                2.0.4
# click                             8.0.4
# colorama                          0.4.4
# cryptography                      37.0.2
# cycler                            0.11.0
# decorator                         5.1.1
# defusedxml                        0.7.1
# despatch                          0.2.0
# entrypoints                       0.3
# et-xmlfile                        1.1.0
# fastcache                         1.1.0
# flake8                            4.0.1
# future                            0.18.2
# geomet                            0.3.0
# h5py                              3.6.0
# html5lib                          1.1
# idna                              3.3
# importlib-metadata                4.11.3
# iniconfig                         1.1.1
# ipykernel                         5.3.4
# ipython                           7.21.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.6.5
# isodate                           0.6.0
# jdcal                             1.4.1
# jedi                              0.18.0
# Jinja2                            3.0.3
# json5                             0.9.5
# jsonschema                        3.2.0
# jupyter-client                    6.1.7
# jupyter-console                   6.4.0
# jupyter-contrib-core              0.3.3
# jupyter-contrib-nbextensions      0.5.1
# jupyter-core                      4.6.3
# jupyter-highlight-selected-word   0.2.0
# jupyter-latex-envs                1.4.6
# jupyter-nbextensions-configurator 0.4.1
# jupyterlab                        2.2.10
# jupyterlab-server                 1.2.0
# jupyterlab-widgets                1.0.0
# keyring                           23.4.0
# kiwisolver                        1.3.2
# lerc                              3.0
# lxml                              4.8.0
# MarkupSafe                        2.0.1
# matplotlib                        3.4.3
# mccabe                            0.7.0
# mistune                           0.8.4
# mkl-fft                           1.3.0
# mkl-random                        1.2.2
# mkl-service                       2.3.0
# mpmath                            1.2.1
# msrest                            0.6.21
# mypy-extensions                   0.4.3
# nbconvert                         5.6.1
# nbformat                          5.1.3
# netCDF4                           1.5.7
# networkx                          2.7.1
# nose                              1.3.7
# notebook                          5.7.10
# ntlm-auth                         1.4.0
# numexpr                           2.8.1
# numpy                             1.20.1
# oauthlib                          3.2.0
# olefile                           0.46
# openpyxl                          3.0.9
# packaging                         21.3
# pandas                            1.3.5
# pandocfilters                     1.5.0
# parso                             0.8.3
# pathspec                          0.9.0
# pefile                            2019.4.18
# pickleshare                       0.7.5
# Pillow                            9.1.0
# pip                               22.1.2
# platformdirs                      2.4.0
# pluggy                            0.13.1
# pro-notebook-integration          2.5
# prometheus-client                 0.8.0
# prompt-toolkit                    3.0.5
# protobuf                          3.19.1
# psutil                            5.8.0
# py                                1.11.0
# pycodestyle                       2.8.0
# pycparser                         2.21
# pyflakes                          2.4.0
# Pygments                          2.9.0
# PyJWT                             2.4.0
# pyodbc                            4.0.32
# pyOpenSSL                         22.0.0
# pyparsing                         3.0.4
# PyPDF2                            1.26.0
# pyrsistent                        0.18.0
# pyshp                             2.1.3
# PySocks                           1.7.1
# pytest                            6.2.4
# python-certifi-win32              1.7.dev1+g24a5d1b
# python-dateutil                   2.8.2
# pytz                              2022.1
# pywin32-ctypes                    0.2.0
# pywinpty                          2.0.1
# PyYAML                            6.0
# pyzmq                             22.2.1
# regex                             2022.3.15
# requests                          2.27.1
# requests-kerberos                 0.12.0
# requests-negotiate-sspi           0.0.0
# requests-ntlm                     1.1.0
# requests-oauthlib                 1.3.0
# requests-toolbelt                 0.9.1
# saspy                             3.7.8
# scipy                             1.6.2
# Send2Trash                        1.8.0
# setuptools                        60.10.0
# simplegeneric                     0.8.1
# six                               1.16.0
# SQLAlchemy                        1.3.12
# swat                              1.9.3
# sympy                             1.9
# terminado                         0.13.1
# testpath                          0.5.0
# toml                              0.10.2
# tomli                             1.2.2
# tornado                           6.1
# traitlets                         5.1.1
# typed-ast                         1.4.3
# typing_extensions                 4.1.1
# ujson                             5.1.0
# urllib3                           1.26.8
# wcwidth                           0.2.5
# webencodings                      0.5.1
# wheel                             0.37.1
# widgetsnbextension                3.5.2
# win-inet-pton                     1.1.0
# wincertstore                      0.2
# winkerberos                       0.8.0
# wrapt                             1.13.3
# x86cpu                            0.4
# xarray                            0.20.1
# xlrd                              2.0.1
# xlwt                              1.3.0
# zipp                              3.7.0

# %% [markdown]
# ### Installed Packages Screenshot

# %% [markdown]
# ![Packages1.png](attachment:Packages1.png)
# ![Packages2.png](attachment:Packages2.png)
# ![Packages3.png](attachment:Packages3.png)
